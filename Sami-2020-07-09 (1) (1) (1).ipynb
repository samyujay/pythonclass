# %%
import numpy as np
from matplotlib import pyplot
import pandas

x = np.linspace(0, 10 * np.pi, 100)

df = pandas.DataFrame({'X':x, 'Y':np.sin(x)})

df.plot(subplots = True, layout = (2, 1))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd7f0f53668>],
# ...
#       dtype=object)

# %%
df
# Out:
#             X             Y
# 0    0.000000  0.000000e+00
# 1    0.317333  3.120334e-01
# 2    0.634665  5.929079e-01
# 3    0.951998  8.145760e-01
# 4    1.269330  9.549022e-01
# ..        ...           ...
# 95  30.146596 -9.549022e-01
# 96  30.463929 -8.145760e-01
# 97  30.781261 -5.929079e-01
# 98  31.098594 -3.120334e-01
# 99  31.415927 -1.224647e-15
#
# [100 rows x 2 columns]

# %%
d = {"Name": ['Vishy', 'Mayur', 'Shilpa',' Nandini','Sami','Jay','Laxmi','Python' ], "Ages":[45, 5, 40, 10, 10, 43, 40, 40]}
print(d)
# Out:
# {'Name': ['Vishy', 'Mayur', 'Shilpa', ' Nandini', 'Sami', 'Jay', 'Laxmi', 'Python'], 'Ages': [45, 5, 40, 10, 10, 43, 40, 40]}

# %%
print(pandas.DataFrame(d))
# Out:
#        Name  Ages
# 0     Vishy    45
# 1     Mayur     5
# 2    Shilpa    40
# 3   Nandini    10
# 4      Sami    10
# 5       Jay    43
# 6     Laxmi    40
# 7    Python    40

# %%
df = pandas.DataFrame(d)
df.plot.barh(x = "Name", y = "Ages", rot = 0, color = "red")

# %%
df = pandas.DataFrame({'Name':['A', 'B', 'C'],
                      'Age':[4, 7, 3]
                      'Money':[1, 5, 7]})

# %%
df.plot.barh(rot = 0)

# %%
import pandas

class school(object):
    def __init__(self):
        self.id = 0
        self.data = {'Name': {},
                    'Age' :{},
                    'Grade': {}}
   
    def addStudent(self, name, age, grade):
        self.id = self.id + 1
        self.data['Name'][self.id] = name
        self.data['Age'][self.id] = age
        self.data['Grade'][self.id] = grade
   
    def getData(self):
        return (pandas.DataFrame(self.data))
    
    def removeStudent(self.id):
        self.data = pandas.DataFrame(self.data).drop([id], axis = 0).to_dict()


mySchool = school()

mySchool.addStudent('Nandini', 10, '5th')
mySchool.addStudent('Sami', 10, '5th')
mySchool.addStudent('Mayur', 5, 'KG')
mySchool.addStudent('Daksh', 8, '3rd')
mySchool.addStudent('Aarna', 10, '5th')
mySchool.addStudent('Swathi', 10, '5th')
mySchool.addStudent('Mahi', 10, '5th')

df = mySchool.getData()

df.plot.bar(x = 'Name', y = 'Age', rot = 0, color = 'cyan')

# %%
Class Store(object):
    def__init__(self, StoreName, DateOfOpening, Adress, PhoneNum):
        self.id = 0
        self.name = StoreName
        self.date = DateOfOpening
        self.
        self.data = {'Name'{},
                    'Price'{},
                    'Qty'{},}
        
    def addDress (slef, name, price, qty)
        self.id = self.id + 1
        self.data['Name'][self.id] = name
        self.data['Price'][self.id] = price
        self.data['Qty'][self.id] = qty
        
    def getData(self):
        return (pandas.DataFrame(self.data))
    
    def sellDress(self, id):
        self.data = pandas.DataFrame(self.data).drop([id], axis = 0).to_dict()
        
    def getStoreName(self):
        return(self.name)
        
    def getDateOfOpening(self):
        return(self.date)
    
    def getAddress(self):
        return(self.address)
    
    def getPhoneNum(self):
        return(self.phone)
        
        
myStore = Store(StoreName = Fashion Store
               DateOfOpening = 2021-10-12
               Adress = 13 Fashion Grove Ave. NY
               PhoneNum = 283-182-2631)
myStore.addDress('Leggings', 7, 21)
myStore.addDress('Jeans', 5, 18)
myStore.addDress('Shorts', 10, 23)
myStore.addDress('Frock', 12, 15)
myStore.addDress('Shirts', 4, 24)
myStore.addDress('Fringe Shirts',12, 32)
myStore.addDress('Swimsuit Top', 10, 12)
myStore.addDress('SwimSuit Short', 12, 12)
myStore.addDress('Tops', 14, 28)
myStore.addDress('Dress', 12, 23)
myStore.addDress('Sweater', 7, 35)

df = myStore.getData()

df.plot.bar(x = 'Name', y = 'Price', rot = 0, color = 'cyan')

# %%
import pandas

class Store(object):
    def __init__(self, StoreName, DateOfOpening, Address, phoneNum):
        self.id = 0
        self.name = StoreName
        self.date = DateOfOpening
        self.address = Address
        self.phone = phoneNum
        self.data = {'Name':{},
                    'Price':{},
                    'Qty':{}}
        
    def addDress (self, name, price, qty):
        self.id = self.id + 1
        self.data['Name'][self.id] = name
        self.data['Price'][self.id] = price
        self.data['Qty'][self.id] = qty
        
    def getData(self):
        return (pandas.DataFrame(self.data))
    
    def sellDress(self, id):
        self.data = pandas.DataFrame(self.data).drop([id], axis = 0).to_dict()
        
    def getStoreName(self):
        return(self.name)
        
    def getDateOfOpening(self):
        return(self.date)
    
    def getAddress(self):
        return(self.address)
    
    def getPhoneNum(self):
        return(self.phone)
        
        
myStore = Store(StoreName = 'Fashion Store',
               DateOfOpening = '2021-10-12',
               Address = '13 Fashion Grove Ave. NY',
               phoneNum = '283-182-2631')
myStore.addDress('Leggings', 7, 21)
myStore.addDress('Jeans', 5, 18)
myStore.addDress('Shorts', 10, 23)
myStore.addDress('Frock', 12, 15)
myStore.addDress('Shirts', 4, 24)
myStore.addDress('Fringe Shirts',12, 32)
myStore.addDress('Swimsuit Top', 10, 12)
myStore.addDress('SwimSuit Short', 12, 12)
myStore.addDress('Tops', 14, 28)
myStore.addDress('Dress', 12, 23)
myStore.addDress('Sweater', 7, 35)

df = myStore.getData()

df.plot.barh(x = 'Name', y = 'Price', rot = 0, color = 'blue')
